# %% [markdown]
# ## Building the ClinVar TP53 Dataset
# ---
#
# #### **Project Objectives**:
#
# **1) Downloading the raw ClinVar dataset**
#
# - Downloaded from: [https://ftp.ncbi.nlm.nih.gov/pub/clinvar/vcf_GRCh38/archive/](https://ftp.ncbi.nlm.nih.gov/pub/clinvar/vcf_GRCh38/archive/)
# - Loading the dataset into a pandas DataFrame.
# - Reviewing columns and data types.
# - Identifying potential features.
#
# **2) Initial data cleaning (`1`)**
#
# - Filtering for only the **TP53** target gene.
# - Removing duplicates and incomplete variant records.
# - Removing metadata (non-informative features lacking biological relevance).
# - Identifying missing values (NaN) and applying imputation methods.
#
# **3) Engineering the target variable (binary classification)**
#
# - For binary classification, focusing solely on **benign** and **pathogenic** labels.
# - Removing all other variant types: **VUS**, **conflicting**, and **-1**.
# - Mapping: `likely benign` → **benign** and `likely pathogenic` → **pathogenic**.
#
# **4) Integrating VEP (Variant Effect Predictor) annotations**
#
# - Using the Ensembl REST API to fetch additional annotations: [https://rest.ensembl.org/#VEP](https://rest.ensembl.org/#VEP)
# - Goal: Create an extended dataset with enriched annotations to improve subsequent model performance.
#
# **5) Cleaning the extended dataset (`2`)**
#
# - Removing variants containing 'NA' values.
# - Filtering out variants without any VEP annotations.
# - Performing complete encoding of categorical annotations.
#
# **6) Forming the final feature set**
#
# - Defining a minimal, interpretable set of features.
# - Finalizing a cleaned dataset ready for training various ML models.

# %% [markdown]
# ---

# %%
#libraries for this phase
from pathlib import Path
import pandas as pd
import numpy as np
import os
from pathlib import Path

# %% [markdown]
# Local project folder structure:
#
# Project root: Binary Classification
#
# Folders: raw data and notebooks

# %%
current = os.getcwd()
parent_dir = Path.cwd().parent
for root,dirs,files in os.walk(parent_dir):
    for file in files:
        if file.endswith('_raw.txt'):
            print(root)
            raw_file_path = os.path.join(root,file)
# Out:
# c:\Users\Admin\Binary Classification\raw data

# %%
raw_data_iterator = pd.read_csv(
    raw_file_path,
    sep='\t',
    chunksize=200000,
    iterator=True
)
#TexTfile obj because of the file size

# %%
dataset = []
for chunk in raw_data_iterator:
    dataset.append(chunk)
dataset = pd.concat(dataset)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12468\4095176858.py:2: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in raw_data_iterator:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12468\4095176858.py:2: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in raw_data_iterator:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12468\4095176858.py:2: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in raw_data_iterator:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12468\4095176858.py:2: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in raw_data_iterator:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12468\4095176858.py:2: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in raw_data_iterator:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12468\4095176858.py:2: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in raw_data_iterator:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12468\4095176858.py:2: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in raw_data_iterator:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12468\4095176858.py:2: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in raw_data_iterator:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12468\4095176858.py:2: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in raw_data_iterator:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12468\4095176858.py:2: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in raw_data_iterator:

# %%
dataset.shape
# Out:
# (8364862, 43)

# %%
dataset = dataset[dataset['GeneSymbol']=='TP53'] #tp53

# %%
# Filter dataset to keep only GRCh38 assembly (newer version)
# Rationale: GRCh38 contains updated genome annotations and corrections compared to GRCh37
dataset = dataset[dataset['Assembly'] == 'GRCh38']

# %%
dataset = dataset[dataset['Assembly']=='GRCh38']

# %%
dataset['Assembly'].value_counts() # GRCh38 - 3758
# Out:
# Assembly
# GRCh38    3758
# Name: count, dtype: int64

# %%
dataset.duplicated().any()
# Out:
# np.False_

# %%
dataset.isnull().any()
dataset.isna().any().sum()
# Out:
# np.int64(0)

# %%
dataset.columns
# Out:
# Index(['#AlleleID', 'Type', 'Name', 'GeneID', 'GeneSymbol', 'HGNC_ID',
#        'ClinicalSignificance', 'ClinSigSimple', 'LastEvaluated', 'RS# (dbSNP)',
#        'nsv/esv (dbVar)', 'RCVaccession', 'PhenotypeIDS', 'PhenotypeList',
#        'Origin', 'OriginSimple', 'Assembly', 'ChromosomeAccession',
#        'Chromosome', 'Start', 'Stop', 'ReferenceAllele', 'AlternateAllele',
#        'Cytogenetic', 'ReviewStatus', 'NumberSubmitters', 'Guidelines',
#        'TestedInGTR', 'OtherIDs', 'SubmitterCategories', 'VariationID',
#        'PositionVCF', 'ReferenceAlleleVCF', 'AlternateAlleleVCF',
#        'SomaticClinicalImpact', 'SomaticClinicalImpactLastEvaluated',
#        'ReviewStatusClinicalImpact', 'Oncogenicity',
#        'OncogenicityLastEvaluated', 'ReviewStatusOncogenicity',
#        'SCVsForAggregateGermlineClassification',
#        'SCVsForAggregateSomaticClinicalImpact',
#        'SCVsForAggregateOncogenicityClassification'],
#       dtype='object')

# %% [markdown]
# ##### 2) Initial Dataset Cleaning
#
# > Dropping all columns except the identification columns necessary for subsequent VEP annotation integration.
#
# - **Chromosome** - Required for precise genomic location
# - **Start** - Unique variant position (I'm only tracking single nucleotide changes, so the **Stop** column is not needed)
# - **ReferenceAlleleVCF** - Reference nucleotide
# - **AlternativeAlleleVCF** - Alternative/mutated nucleotide
# - **GeneSymbol** - Confirmation that the variant is from the target gene in this project (**TP53**)
# - **ClinSigSimple** - Binary label (0 and 1)

# %% [markdown]
# [Chromosome, Start, ReferenceAlleleVCF, AlternateAlleleVCF]

# %%
selected_cols = ['Chromosome','Start','ReferenceAlleleVCF','AlternateAlleleVCF','GeneSymbol','ClinSigSimple']
dataset = dataset[selected_cols]

# %%
dataset.isna().any()
# Out:
# Chromosome            False
# Start                 False
# ReferenceAlleleVCF    False
# AlternateAlleleVCF    False
# GeneSymbol            False
# ClinSigSimple         False
# dtype: bool

# %%
dataset.isnull().any()
# Out:
# Chromosome            False
# Start                 False
# ReferenceAlleleVCF    False
# AlternateAlleleVCF    False
# GeneSymbol            False
# ClinSigSimple         False
# dtype: bool

# %%
dataset['Chromosome'].value_counts()
# Out:
# Chromosome
# 17    3674
# 17      84
# Name: count, dtype: int64

# %%
# Standardizing the 'Chromosome' column, merging mixed dtype (str) and (int) into `str` type
dataset['Chromosome'] = dataset['Chromosome'].astype(str)

# %%
dataset['Chromosome'].value_counts()
# Out:
# Chromosome
# 17    3758
# Name: count, dtype: int64

# %%
# odbacivanje svih vrednosti koji su 'na'
dataset = dataset[dataset['Chromosome']=='17']

# %% [markdown]
# ### `ReferenceAlleleVCF` and `AlternateAlleleVCF` contain specific nucleotides (A/C/G/T) and are aligned with the reference genome. They are precise sources of information and essential for VEP annotation.
#
# ### These two columns require additional cleaning as they contain not only single characters but also longer sequences. This indicates variant types like insertions and deletions affecting larger gene segments, which are not the current focus of this research. The focus is on single nucleotide variants (SNVs) and determining their pathogenicity.
#
# #### Alternative: Also filter for valid nucleotides only

# %%
dataset['ReferenceAlleleVCF'].value_counts()
# Out:
# ReferenceAlleleVCF
# G                           948
# C                           890
# A                           576
# T                           555
# GC                           41
#                            ...
# GGAGTCTTCCAGTGTGATGATGGT      1
# ACTATGTCG                     1
# GCGGCTCATAGGGCACC             1
# AGTTGGCAAAACATCTT             1
# ATGTAGT                       1
# Name: count, Length: 416, dtype: int64

# %%
# Keeping the rows with only 1 Character AKA nucleotide 
dataset = dataset[(dataset['ReferenceAlleleVCF'].str.len()==1)&(dataset['AlternateAlleleVCF'].str.len()==1)]
dataset['ReferenceAlleleVCF'].value_counts()
# Out:
# ReferenceAlleleVCF
# G    852
# C    812
# A    515
# T    503
# Name: count, dtype: int64

# %%
dataset['AlternateAlleleVCF'].value_counts()
# Out:
# AlternateAlleleVCF
# A    778
# T    704
# C    632
# G    568
# Name: count, dtype: int64

# %%
dataset['GeneSymbol'].value_counts()
# Out:
# GeneSymbol
# TP53    2682
# Name: count, dtype: int64

# %%
dataset = dataset.reset_index(drop=True)
dataset
# Out:
#      Chromosome    Start ReferenceAlleleVCF AlternateAlleleVCF GeneSymbol  \
# 0            17  7674221                  G                  A       TP53
# 1            17  7674191                  C                  T       TP53
# 2            17  7674230                  C                  A       TP53
# 3            17  7674208                  A                  G       TP53
# 4            17  7676154                  G                  C       TP53
# ...         ...      ...                ...                ...        ...
# 2677         17  7676274                  T                  A       TP53
# 2678         17  7676351                  T                  A       TP53
# 2679         17  7676405                  T                  G       TP53
# 2680         17  7676517                  T                  C       TP53
# 2681         17  7673785                  C                  A       TP53
#
#       ClinSigSimple
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ...             ...
# 2677             -1
# 2678             -1
# 2679             -1
# 2680             -1
# 2681             -1
#
# [2682 rows x 6 columns]

# %% [markdown]
# Further filter the dataset according to the coordinates/location of the gene (TP53) provided on the official Ensembl website [https://www.ensembl.org/Homo_sapiens/Gene/Summary?db=core;g=ENSG00000141510;r=17:7661779-7687546]
#
# **location** - Chromosome 17: 7,661,779-7,687,546 reverse strand.

# %%
tp53_start = 7661779
tp53_end = 7687546

dataset = dataset[
    (dataset['Start']>=tp53_start) &
    (dataset['Start']<=tp53_end)
]

dataset
# Out:
#      Chromosome    Start ReferenceAlleleVCF AlternateAlleleVCF GeneSymbol  \
# 0            17  7674221                  G                  A       TP53
# 1            17  7674191                  C                  T       TP53
# 2            17  7674230                  C                  A       TP53
# 3            17  7674208                  A                  G       TP53
# 4            17  7676154                  G                  C       TP53
# ...         ...      ...                ...                ...        ...
# 2677         17  7676274                  T                  A       TP53
# 2678         17  7676351                  T                  A       TP53
# 2679         17  7676405                  T                  G       TP53
# 2680         17  7676517                  T                  C       TP53
# 2681         17  7673785                  C                  A       TP53
#
#       ClinSigSimple
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ...             ...
# 2677             -1
# 2678             -1
# 2679             -1
# 2680             -1
# 2681             -1
#
# [2678 rows x 6 columns]

# %% [markdown]
# ### 3) Target feature -> __ClinSigSimple__
# - label 0 `benign`/`likely bening` -> **benign**
#
# - label 1 `pathogenic`/`likely pathogenic` -> **pathogenic**
#
# - label -1 ‘‘conflicting interpretation of pathogenicity’’  variants without clear effects on the carrier (drop)

# %%
dataset = dataset[dataset['ClinSigSimple']!=-1]

# %%
dataset['ClinSigSimple'].value_counts()
# Out:
# ClinSigSimple
# 0    2026
# 1     621
# Name: count, dtype: int64

# %% [markdown]
# #### 4) Integration of VEP variants (ENSEBML REST API) [ https://rest.ensembl.org/documentation/info/vep_region_post ]

# %% [markdown]
# In practice, the Ensembl VEP returns multiple annotations per variant because a single variant can have multiple transcripts.
#
# In scientific papers, the practice is to use a representative annotation per variant, marked as canonical. This way, I would establish uniformity in the data I retrieve for the variants in the current dataset.
#
# I also came across this rule in the paper 'Annotating and prioritizing genomic variants using the Ensembl Variant Effect Predictor—A tutorial',
#
# Hunt SE et al. (2021) [https://pmc.ncbi.nlm.nih.gov/articles/PMC7613081/]

# %% [markdown]
# The `plugin` section on the page refers specifically to the additional annotations I will integrate into the dataset.
#
# - AlphaMissense
#
# -  Blosum62
#
# - CADD (cadd_raw & cadd_phred)
#
# -  LoF
#
# - PolyPhen score
#
# - Sift_score
#
# + IMPACT which request returns always.
#
# After several unsuccessful attempts with the GET method for a single variant, I tried a POST request [https://rest.ensembl.org/documentation/info/vep_region_post] to retrieve annotations for a larger number of variants.
#
# The format used for the POST request is: [Chromosome Start . ReferenceAlleleVCF AlternateAlleleVCF]

# %%
dataset['vcf_format'] = dataset.apply(
    lambda row: f"{row['Chromosome']} {row['Start']} . {row['ReferenceAlleleVCF']} {row['AlternateAlleleVCF']}", 
    axis=1
)

variantsParams = dataset['vcf_format'].to_list()
print(len(variantsParams))
_test = variantsParams
# 50 test
# Out:
# 2647
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12468\3547526549.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['vcf_format'] = dataset.apply(

# %% [markdown]
# For the API call, I followed the official example at the bottom of the page [https://rest.ensembl.org/documentation/info/vep_region_post] with minor modifications.
#
# In the param variable, I defined the final set of available parameters after several attempts.

# %%
chunk = 200
for i in variantsParams:
    print(i)
# Out:
# 17 7674221 . G A
# 17 7674191 . C T
# 17 7674230 . C A
# 17 7674208 . A G
# 17 7676154 . G C
# 17 7674216 . C A
# 17 7675143 . C A
# 17 7674238 . C T
# 17 7674229 . C T
# 17 7674220 . C T
# 17 7675214 . A G
# 17 7673806 . C A
# 17 7674241 . G A
# 17 7676011 . T A
# 17 7673776 . G A
# 17 7674230 . C T
# 17 7673802 . C T
# 17 7673554 . C A
# 17 7673781 . C G
# 17 7675161 . G T
# 17 7675161 . G A
# 17 7676264 . C A
# 17 7674193 . A T
# 17 7675088 . C T
# 17 7670678 . A G
# 17 7675200 . C G
# 17 7673745 . T A
# 17 7670699 . C T
# 17 7674965 . G A
# 17 7674872 . T G
# 17 7673766 . T A
# 17 7668434 . T G
# 17 7675070 . C A
# 17 7676564 . C G
# 17 7670669 . G T
# 17 7676230 . G A
# 17 7674945 . G A
# 17 7674894 . G A
# 17 7674892 . T C
# 17 7673803 . G A
# 17 7673610 . T C
# 17 7670658 . T C
# 17 7670616 . G A
# 17 7674859 . C T
# 17 7675212 . A G
# 17 7673728 . C A
# 17 7673523 . A G
# 17 7674944 . C A
# 17 7674227 . T C
# 17 7673733 . T C
# 17 7687373 . T G
# 17 7676196 . G C
# 17 7676121 . G A
# 17 7676567 . C T
# 17 7676040 . C T
# 17 7675146 . G A
# 17 7675145 . C T
# 17 7675140 . G A
# 17 7675127 . A C
# 17 7675124 . T C
# 17 7675077 . G A
# 17 7674959 . G C
# 17 7674951 . G A
# 17 7674927 . G A
# 17 7673698 . T A
# 17 7676561 . G A
# 17 7673793 . G A
# 17 7673566 . T G
# 17 7675208 . C G
# 17 7673762 . T G
# 17 7676202 . T C
# 17 7676122 . C A
# 17 7673838 . C G
# 17 7666193 . C T
# 17 7675205 . T A
# 17 7674966 . C T
# 17 7675188 . G T
# 17 7676122 . C G
# 17 7669659 . A T
# 17 7674907 . G C
# 17 7674913 . C G
# 17 7675192 . G A
# 17 7676533 . T G
# 17 7674854 . C A
# 17 7673550 . T G
# 17 7675202 . A T
# 17 7674245 . T A
# 17 7676117 . G A
# 17 7674911 . T C
# 17 7675999 . A G
# 17 7676090 . C G
# 17 7676421 . A G
# 17 7673627 . A G
# 17 7673607 . T G
# 17 7676216 . T C
# 17 7674988 . A G
# 17 7676375 . T C
# 17 7673780 . T C
# 17 7669621 . A G
# 17 7676292 . G A
# 17 7674946 . G A
# 17 7675153 . G T
# 17 7674186 . G A
# 17 7675043 . A G
# 17 7674981 . A G
# 17 7676286 . A G
# 17 7670662 . T C
# 17 7676512 . T C
# 17 7676270 . G A
# 17 7673529 . T A
# 17 7676374 . G A
# 17 7676529 . T A
# 17 7669608 . G A
# 17 7675126 . G A
# 17 7676012 . G A
# 17 7670734 . G A
# 17 7676054 . G A
# 17 7673798 . A G
# 17 7676027 . C T
# 17 7669624 . C T
# 17 7675150 . G C
# 17 7674304 . C T
# 17 7674302 . C A
# 17 7676105 . G T
# 17 7676129 . A C
# 17 7674892 . T G
# 17 7676419 . A G
# 17 7676513 . C G
# 17 7676228 . C G
# 17 7676513 . C A
# 17 7673695 . G A
# 17 7676180 . A C
# 17 7674986 . T C
# 17 7675123 . G A
# 17 7674978 . G A
# 17 7675141 . G C
# 17 7675171 . A G
# 17 7674172 . G C
# 17 7676285 . G A
# 17 7674983 . C A
# 17 7675177 . C A
# 17 7676060 . G A
# 17 7670719 . C T
# 17 7675985 . G T
# 17 7670723 . A G
# 17 7676120 . C G
# 17 7676514 . C T
# 17 7673589 . G A
# 17 7669678 . G T
# 17 7676111 . T G
# 17 7674294 . G A
# 17 7676045 . A G
# 17 7674852 . A C
# 17 7673708 . A T
# 17 7669663 . A G
# 17 7670601 . T A
# 17 7675195 . C T
# 17 7674898 . A G
# 17 7676126 . T G
# 17 7674874 . G A
# 17 7669763 . C G
# 17 7679754 . A G
# 17 7673202 . C A
# 17 7670660 . A C
# 17 7676382 . C G
# 17 7675052 . C G
# 17 7674246 . G T
# 17 7676086 . A T
# 17 7669689 . G C
# 17 7670715 . T G
# 17 7675089 . G T
# 17 7674968 . A G
# 17 7676133 . G A
# 17 7676070 . T G
# 17 7673762 . T C
# 17 7669609 . T G
# 17 7675221 . T G
# 17 7677724 . A G

# %%
import requests
import json

server = "https://rest.ensembl.org" 
ext = "/vep/homo_sapiens/region"

headers = { 
    "Content-Type": "application/json",
    "Accept": "application/json"
} 

variant = _test[:1]  # 50 varijanti test

data = {
    "variants": variant
} 
param ={ 
    'canonical':1, # returns canonical transkript 
    'CADD':1, 
    'AlphaMissense':1,
    'Blosum62':1,
    'LoF':1,
    'REVEL':1
}
try:
    r = requests.post(server + ext, headers=headers, json=data,params=param)
    print(f"Connection status: {r.status_code}")
except:
    ConnectionError(f"{r.status_code}")

print(r.json())
# Out:
# Connection status: 200
# [{'assembly_name': 'GRCh38', 'seq_region_name': '17', 'strand': 1, 'end': 7674221, 'input': '17 7674221 . G A', 'colocated_variants': [{'strand': 1, 'seq_region_name': '17', 'id': 'CM010465', 'start': 7674221, 'clinvar_somatic_classification': 'Neoplasm(oncogenicity:Oncogenic)', 'allele_string': 'HGMD_MUTATION', 'phenotype_or_disease': 1, 'end': 7674221}, {'seq_region_name': '17', 'id': 'CM900211', 'strand': 1, 'end': 7674221, 'phenotype_or_disease': 1, 'allele_string': 'HGMD_MUTATION', 'clinvar_somatic_classification': 'Neoplasm(oncogenicity:Oncogenic)', 'start': 7674221}, {'seq_region_name': '17', 'var_synonyms': {'COSMIC': ['COSM10656']}, 'id': 'COSV52662035', 'strand': 1, 'end': 7674221, 'somatic': 1, 'allele_string': 'COSMIC_MUTATION', 'phenotype_or_disease': 1, 'start': 7674221, 'clinvar_somatic_classification': 'Neoplasm(oncogenicity:Oncogenic)'}, {'somatic': 1, 'end': 7674221, 'phenotype_or_disease': 1, 'allele_string': 'COSMIC_MUTATION', 'start': 7674221, 'clinvar_somatic_classification': 'Neoplasm(oncogenicity:Oncogenic)', 'id': 'COSV52797251', 'var_synonyms': {'COSMIC': ['COSM11564']}, 'seq_region_name': '17', 'strand': 1}, {'strand': 1, 'seq_region_name': '17', 'var_synonyms': {'COSMIC': ['COSM44920']}, 'id': 'COSV53097881', 'phenotype_or_disease': 1, 'allele_string': 'COSMIC_MUTATION', 'clinvar_somatic_classification': 'Neoplasm(oncogenicity:Oncogenic)', 'start': 7674221, 'end': 7674221, 'somatic': 1}, {'end': 7674221, 'frequencies': {'A': {'gnomadg_afr': 0, 'gnomade': 6.157e-06, 'gnomadg': 0, 'gnomade_amr': 2.236e-05, 'gnomadg_asj': 0, 'gnomadg_ami': 0, 'gnomadg_sas': 0, 'gnomade_mid': 0, 'gnomade_asj': 0, 'gnomadg_nfe': 0, 'gnomade_afr': 0, 'gnomadg_fin': 0, 'gnomade_sas': 1.159e-05, 'gnomadg_eas': 0, 'gnomadg_remaining': 0, 'gnomadg_amr': 0, 'gnomade_remaining': 0, 'gnomade_fin': 0, 'gnomade_eas': 0, 'gnomadg_mid': 0, 'gnomade_nfe': 6.296e-06}}, 'clinvar_somatic_classification': 'Neoplasm(oncogenicity:Oncogenic)', 'start': 7674221, 'allele_string': 'G/A/C/T', 'phenotype_or_disease': 1, 'clin_sig_allele': 'T:likely_benign;A:pathogenic/likely_pathogenic;C:pathogenic;A:uncertain_significance;C:likely_pathogenic;A:pathogenic', 'var_synonyms': {'OMIM': [191170.0001], 'PhenCode': ['TP53_g.13379C>T'], 'ClinVar': ['RCV000444845', 'RCV000442243', 'RCV000441557', 'RCV000441091', 'RCV000440560', 'RCV000440422', 'RCV000438698', 'RCV000436398', 'RCV000435803', 'RCV000434504', 'RCV000433905', 'RCV000431689', 'RCV000431508', 'RCV000430543', 'RCV000429884', 'RCV000429777', 'RCV000425682', 'RCV000425083', 'RCV000424415', 'RCV000424308', 'RCV000423804', 'RCV000423184', 'RCV000419857', 'RCV000419150', 'RCV000419032', 'RCV000418495', 'RCV000213057', 'RCV000168242', 'RCV000115735', 'RCV000013140', 'VCV000012347', 'RCV000785485', 'RCV000735293', 'RCV001374442', 'RCV001271100', 'RCV001255674', 'RCV003162243', 'RCV003149569', 'RCV003105772', 'RCV000626118', 'RCV000444519', 'RCV000444427', 'RCV000444356', 'RCV000441711', 'RCV000441010', 'RCV000440334', 'RCV000437882', 'RCV000436038', 'RCV000435353', 'RCV000435050', 'RCV000433611', 'RCV000432931', 'RCV000432207', 'RCV000633396', 'RCV000430735', 'RCV000427948', 'RCV000427544', 'RCV000425782', 'RCV000425394', 'RCV000425100', 'RCV000424776', 'RCV000423297', 'RCV000422668', 'RCV000420498', 'RCV000418362', 'RCV000417693', 'VCV000376652', 'RCV001026425', 'RCV004022238', 'RCV001175916', 'VCV000918353', 'RCV003460463', 'RCV003318332', 'RCV004745154'], 'UniPro': []}, 'id': 'rs121912651', 'seq_region_name': '17', 'pubmed': [25741868, 24033266, 26900293, 32293552, 25157968, 26619011, 25105660, 16489069, 17606709, 30744407, 1631137, 1978757, 21343334, 8099841, 8425176, 8527048, 9598730, 9825943, 12826609, 17427234, 20013323, 28664506, 37182128, 34771529, 34178683, 36866106, 35483882, 37391803, 38310289, 38413718, 39457600, 39208653, 39488539], 'clin_sig': ['uncertain_significance', 'likely_benign', 'likely_pathogenic', 'pathogenic'], 'strand': 1}], 'allele_string': 'G/A', 'transcript_consequences': ...

# %%
result = r.json()
print(result[0]) #json string
# Out:
# {'assembly_name': 'GRCh38', 'seq_region_name': '17', 'strand': 1, 'end': 7674221, 'input': '17 7674221 . G A', 'colocated_variants': [{'strand': 1, 'seq_region_name': '17', 'id': 'CM010465', 'start': 7674221, 'clinvar_somatic_classification': 'Neoplasm(oncogenicity:Oncogenic)', 'allele_string': 'HGMD_MUTATION', 'phenotype_or_disease': 1, 'end': 7674221}, {'seq_region_name': '17', 'id': 'CM900211', 'strand': 1, 'end': 7674221, 'phenotype_or_disease': 1, 'allele_string': 'HGMD_MUTATION', 'clinvar_somatic_classification': 'Neoplasm(oncogenicity:Oncogenic)', 'start': 7674221}, {'seq_region_name': '17', 'var_synonyms': {'COSMIC': ['COSM10656']}, 'id': 'COSV52662035', 'strand': 1, 'end': 7674221, 'somatic': 1, 'allele_string': 'COSMIC_MUTATION', 'phenotype_or_disease': 1, 'start': 7674221, 'clinvar_somatic_classification': 'Neoplasm(oncogenicity:Oncogenic)'}, {'somatic': 1, 'end': 7674221, 'phenotype_or_disease': 1, 'allele_string': 'COSMIC_MUTATION', 'start': 7674221, 'clinvar_somatic_classification': 'Neoplasm(oncogenicity:Oncogenic)', 'id': 'COSV52797251', 'var_synonyms': {'COSMIC': ['COSM11564']}, 'seq_region_name': '17', 'strand': 1}, {'strand': 1, 'seq_region_name': '17', 'var_synonyms': {'COSMIC': ['COSM44920']}, 'id': 'COSV53097881', 'phenotype_or_disease': 1, 'allele_string': 'COSMIC_MUTATION', 'clinvar_somatic_classification': 'Neoplasm(oncogenicity:Oncogenic)', 'start': 7674221, 'end': 7674221, 'somatic': 1}, {'end': 7674221, 'frequencies': {'A': {'gnomadg_afr': 0, 'gnomade': 6.157e-06, 'gnomadg': 0, 'gnomade_amr': 2.236e-05, 'gnomadg_asj': 0, 'gnomadg_ami': 0, 'gnomadg_sas': 0, 'gnomade_mid': 0, 'gnomade_asj': 0, 'gnomadg_nfe': 0, 'gnomade_afr': 0, 'gnomadg_fin': 0, 'gnomade_sas': 1.159e-05, 'gnomadg_eas': 0, 'gnomadg_remaining': 0, 'gnomadg_amr': 0, 'gnomade_remaining': 0, 'gnomade_fin': 0, 'gnomade_eas': 0, 'gnomadg_mid': 0, 'gnomade_nfe': 6.296e-06}}, 'clinvar_somatic_classification': 'Neoplasm(oncogenicity:Oncogenic)', 'start': 7674221, 'allele_string': 'G/A/C/T', 'phenotype_or_disease': 1, 'clin_sig_allele': 'T:likely_benign;A:pathogenic/likely_pathogenic;C:pathogenic;A:uncertain_significance;C:likely_pathogenic;A:pathogenic', 'var_synonyms': {'OMIM': [191170.0001], 'PhenCode': ['TP53_g.13379C>T'], 'ClinVar': ['RCV000444845', 'RCV000442243', 'RCV000441557', 'RCV000441091', 'RCV000440560', 'RCV000440422', 'RCV000438698', 'RCV000436398', 'RCV000435803', 'RCV000434504', 'RCV000433905', 'RCV000431689', 'RCV000431508', 'RCV000430543', 'RCV000429884', 'RCV000429777', 'RCV000425682', 'RCV000425083', 'RCV000424415', 'RCV000424308', 'RCV000423804', 'RCV000423184', 'RCV000419857', 'RCV000419150', 'RCV000419032', 'RCV000418495', 'RCV000213057', 'RCV000168242', 'RCV000115735', 'RCV000013140', 'VCV000012347', 'RCV000785485', 'RCV000735293', 'RCV001374442', 'RCV001271100', 'RCV001255674', 'RCV003162243', 'RCV003149569', 'RCV003105772', 'RCV000626118', 'RCV000444519', 'RCV000444427', 'RCV000444356', 'RCV000441711', 'RCV000441010', 'RCV000440334', 'RCV000437882', 'RCV000436038', 'RCV000435353', 'RCV000435050', 'RCV000433611', 'RCV000432931', 'RCV000432207', 'RCV000633396', 'RCV000430735', 'RCV000427948', 'RCV000427544', 'RCV000425782', 'RCV000425394', 'RCV000425100', 'RCV000424776', 'RCV000423297', 'RCV000422668', 'RCV000420498', 'RCV000418362', 'RCV000417693', 'VCV000376652', 'RCV001026425', 'RCV004022238', 'RCV001175916', 'VCV000918353', 'RCV003460463', 'RCV003318332', 'RCV004745154'], 'UniPro': []}, 'id': 'rs121912651', 'seq_region_name': '17', 'pubmed': [25741868, 24033266, 26900293, 32293552, 25157968, 26619011, 25105660, 16489069, 17606709, 30744407, 1631137, 1978757, 21343334, 8099841, 8425176, 8527048, 9598730, 9825943, 12826609, 17427234, 20013323, 28664506, 37182128, 34771529, 34178683, 36866106, 35483882, 37391803, 38310289, 38413718, 39457600, 39208653, 39488539], 'clin_sig': ['uncertain_significance', 'likely_benign', 'likely_pathogenic', 'pathogenic'], 'strand': 1}], 'allele_string': 'G/A', 'transcript_consequences':  ...

# %%
for key,value in result[0].items():
    print(key,value) # transcript_consequences = in this nested dict are stored variants information!!!!
# Out:
# assembly_name GRCh38
# seq_region_name 17
# strand 1
# end 7674221
# input 17 7674221 . G A
# colocated_variants [{'strand': 1, 'seq_region_name': '17', 'id': 'CM010465', 'start': 7674221, 'clinvar_somatic_classification': 'Neoplasm(oncogenicity:Oncogenic)', 'allele_string': 'HGMD_MUTATION', 'phenotype_or_disease': 1, 'end': 7674221}, {'seq_region_name': '17', 'id': 'CM900211', 'strand': 1, 'end': 7674221, 'phenotype_or_disease': 1, 'allele_string': 'HGMD_MUTATION', 'clinvar_somatic_classification': 'Neoplasm(oncogenicity:Oncogenic)', 'start': 7674221}, {'seq_region_name': '17', 'var_synonyms': {'COSMIC': ['COSM10656']}, 'id': 'COSV52662035', 'strand': 1, 'end': 7674221, 'somatic': 1, 'allele_string': 'COSMIC_MUTATION', 'phenotype_or_disease': 1, 'start': 7674221, 'clinvar_somatic_classification': 'Neoplasm(oncogenicity:Oncogenic)'}, {'somatic': 1, 'end': 7674221, 'phenotype_or_disease': 1, 'allele_string': 'COSMIC_MUTATION', 'start': 7674221, 'clinvar_somatic_classification': 'Neoplasm(oncogenicity:Oncogenic)', 
# allele_string G/A
# transcript_consequences [{'strand': -1, 'cdna_end': 884, 'gene_symbol': 'TP53', 'sift_score': 0, 'cdna_start': 884, 'sift_prediction': 'deleterious', 'cds_start': 742, 'canonical': 1, 'biotype': 'protein_coding', 'hgnc_id': 'HGNC:11998', 'consequence_terms': ['missense_variant'], 'protein_start': 248, 'alphamissense': {'am_class': 'likely_pathogenic', 'am_pathogenicity': 0.9968}, 'variant_allele': 'A', 'cds_end': 742, 'cadd_raw': 5.203168, 'impact': 'MODERATE', 'blosum62': -3, 'transcript_id': 'ENST00000269305', 'gene_symbol_source': 'HGNC', 'gene_id': 'ENSG00000141510', 'amino_acids': 'R/W', 'cadd_phred': 29.2, 'revel': 0.927, 'codons': 'Cgg/Tgg', 'protein_end': 248}, {'cadd_raw': 5.203168, 'blosum62': -3, 'impact': 'MODERATE', 'transcript_id': 'ENST00000359597', 'gene_symbol_source': 'HGNC', 'polyphen_score': 1, 'gene_id': 'ENSG00000141510', 'amino_acids': 'R/W', 'revel': 0.927, 'cadd_phred': 29.2, 'codons': 'Cgg/Tgg', 'protein_end': 248, 'strand': -1, 'cdna_end': 742, 'gene_symbol': 'TP53', 'sift_score': 0, 'cdna_start': 742, 'cds_start': 742, 'polyphen_prediction': 'probably_damaging', 'sift_prediction': 'deleterious', 'biotype': 'protein_coding', 'consequence_terms': ['missense_variant'], 'hgnc_id': 'HGNC:11998', 'protein_start': 248, 'alphamissense': {'am_class': 'likely_pathogenic', 'am_pathogenicity': 0.9968}, 'variant_allele': 'A', 'cds_end': 742}, {'amino_acids': 'R/W', 'polyphen_score': 1, 'gene_id': 'ENSG00000141510', 'gene_symbol_source': 'HGNC', 'transcript_id': 'ENST00000413465', 'cadd_raw': 5.203168, 'blosum62': -3, 'impact': 'MODERATE', 'protein_end': 248, 'codons': 'Cgg/Tgg', 'revel': 0.927, 'cadd_phred': 29.2, 'polyphen_prediction': 'probably_damaging', 'sift_prediction': 'deleterious', 'cds_start': 742, 'cdna_start': 742, 'sift_score': 0, 'gene_symbol': 'TP53', 'cdna_end': 742, 'strand': -1, 'cds_end': 742, 'variant_allele': 'A', 'alphamissense': {'am_class': 'likely_pathogenic', 'am_pathogenicity': 0.9968}, 'protein_start': 248, 'hgnc_id': 'HGNC:11998', 'consequence_terms': ['missense_variant'], 'biotype': 'protein_coding'}, {'transcript_id': 'ENST00000420246', 'blosum62': -3, 'cadd_raw': 5.203168, 'impact': 'MODERATE', 'gene_id': 'ENSG00000141510', 'amino_acids': 'R/W', 'gene_symbol_source': 'HGNC', 'revel': 0.927, 'cadd_phred': 29.2, 'codons': 'Cgg/Tgg', 'protein_end': 248, 'cdna_end': 875, 'strand': -1, 'sift_prediction': 'deleterious', 'cds_start': 742, 'gene_symbol': 'TP53', 'sift_score': 0, 'cdna_start': 875, 'hgnc_id': 'HGNC:11998', 'consequence_terms': ['missense_variant'], 'protein_start': 248, 'biotype': 'protein_coding', 'cds_end': 742, 'alphamissense': {'am_pathogenicity': 0.9968, 'am_class': 'likely_pathogenic'}, 'variant_allele': 'A'}, {'revel': 0.927, 'cadd_phred': 29.2, 'codons': 'Cgg/Tgg', 'protein_end': 248, 'blosum62': -3, 'impact': 'MODERATE', 'cadd_raw': 5.203168, 'transcript_id': 'ENST00000445888', 'gene_symbol_source': 'HGNC', 'gene_id': 'ENSG00000141510', 'amino_acids': 'R/W', 'biotype': 'protein_coding', 'consequence_terms': ['missense_variant'], 'hgnc_id': 'HGNC:11998', 'protein_start': 248, 'alphamissense': {'am_pathogenicity': 0.9968, 'am_class': 'likely_pathogenic'}, 'variant_allele': 'A', 'cds_end': 742, 'strand': -1, 'cdna_end': 878, 'gene_symbol': 'TP53', 'cdna_start': 878, 'sift_score': 0, 'sift_prediction': 'deleterious', 'cds_start': 742}, {'gene_symbol': 'TP53', 'cdna_start': 875, 'sift_score': 0, 'sift_prediction': 'deleterious', 'cds_start': 742, 'strand': -1, 'cdna_end': 875, 'alphamissense': {'am_pathogenicity': 0.9968, 'am_class': 'likely_pathogenic'}, 'variant_allele': 'A', 'cds_end': 742, 'biotype': 'protein_coding', 'consequence_terms': ['missense_variant'], 'hgnc_id': 'HGNC:11998', 'protein_start': 248, 'gene_symbol_source': 'HGNC', 'gene_id': 'ENSG00000141510', 'amino_acids': 'R/W', 'blosum62': -3, 'impact': 'MODERATE', 'cadd_raw': 5.203168, 'transcript_id': 'ENST00000455263', 'protein_end': 248, 'cadd_phred': 29.2, 'revel': 0.927, 'codons': 'Cgg/Tgg'}, {'cdna_ ...
# id .
# start 7674221
# most_severe_consequence missense_variant

# %%
ciljneAnotacije = result[0]['transcript_consequences']

# %% [markdown]
# The output contains many annotations that are not needed, so I am only looking at the 'transcript_consequences' nested list, which contains annotations relevant for ML.
#
# Also, transcripts contain different keys, which is expected behavior in the context of genomics, as one variant can have multiple transcripts with different functional effects (1 gene = many different products).
#
# For this reason, I will make a selection such that 1 Variant : 1 Transcript (representative)
#
# > The transcript must be canonical:1 and 'protein-coding'

# %%
# transcripts selection
def select_transcript(anotacije):
    is_proteinCoding = [p for p in anotacije if p.get('biotype')=='protein_coding'] # only protein coding hence they can be pathogenic
    is_canonical = [c for c in anotacije if c.get('canonical')==1] # only canonical
    selected = is_canonical[0] if anotacije else is_proteinCoding[0] 
    return selected
selected = select_transcript(ciljneAnotacije)

# %%
rows=[]
for i in range(len(result)):
    transcripts = result[i]['transcript_consequences']
    select = select_transcript(transcripts)
    features = {
    'variant_id': i,
    'cadd_phred': select.get('cadd_phred'),
    'cadd_raw': select.get('cadd_raw'),
    'revel': select.get('revel'),
    'sift_score': select.get('sift_score'),
    'polyphen_score': select.get('polyphen_score'),
    'blosum62': select.get('blosum62'),
    'alphamissense_score': select.get('alphamissense',{}).get('am_pathogenicity'), #alphamissens vraca 2 vrednosti ali uzimam samo prvu tj scor, label mi ne treba
    'impact': select.get('impact'),
    'consequence': (select.get('consequence_terms', [None])[0])
    }   

    rows.append(features)   
print(rows)
# Out:
# [{'variant_id': 0, 'cadd_phred': 29.2, 'cadd_raw': 5.203168, 'revel': 0.927, 'sift_score': 0, 'polyphen_score': None, 'blosum62': -3, 'alphamissense_score': 0.9968, 'impact': 'MODERATE', 'consequence': 'missense_variant'}]

# %% [markdown]
# #### Making dataset from these features

# %%
values = []
for i in rows:
    column_names = i.keys()
    column_values = i.values()
    values.append(list(column_values))

# %%
for i in rows:
    data = list(i.values())
    print(data)
# Out:
# [0, 29.2, 5.203168, 0.927, 0, None, -3, 0.9968, 'MODERATE', 'missense_variant']

# %%
features_df = pd.DataFrame(data=values,columns= column_names)
features_df
# Out:
#    variant_id  cadd_phred  cadd_raw  revel  sift_score polyphen_score  \
# 0           0        29.2  5.203168  0.927           0           None
#
#    blosum62  alphamissense_score    impact       consequence
# 0        -3               0.9968  MODERATE  missense_variant

# %%
# copy of the starting dataset , 50 rows appending to 50 variants (TEST)
dataset_cp = dataset.copy()
dataset_cp = dataset_cp.iloc[:1,:]
dataset_cp
# Out:
#   Chromosome    Start ReferenceAlleleVCF AlternateAlleleVCF GeneSymbol  \
# 0         17  7674221                  G                  A       TP53
#
#    ClinSigSimple        vcf_format
# 0              1  17 7674221 . G A

# %% [markdown]
# Ovde je prikazan integrisani dataset nakon spajanja ClinVar zapisa sa Ensembl VEP anotacijama. Svi atributi nisu namenjeni modeliranju, već služe kao izvor ili meta-informacije

# %%
test_df = pd.concat([dataset_cp,features_df],axis=1) 
test_df
# Out:
#   Chromosome    Start ReferenceAlleleVCF AlternateAlleleVCF GeneSymbol  \
# 0         17  7674221                  G                  A       TP53
#
#    ClinSigSimple        vcf_format  variant_id  cadd_phred  cadd_raw  revel  \
# 0              1  17 7674221 . G A           0        29.2  5.203168  0.927
#
#    sift_score polyphen_score  blosum62  alphamissense_score    impact  \
# 0           0           None        -3               0.9968  MODERATE
#
#         consequence
# 0  missense_variant

# %% [markdown]
# ### Purposefully defined test dataset that will serve for EDA
# (LoF score was not available to retrieve, so it was excluded from the start)

# %%
features_df = test_df.iloc[:,8:]
features_df
# Out:
#    cadd_phred  cadd_raw  revel  sift_score polyphen_score  blosum62  \
# 0        29.2  5.203168  0.927           0           None        -3
#
#    alphamissense_score    impact       consequence
# 0               0.9968  MODERATE  missense_variant

# %% [markdown]
# ### And target:

# %%
target = test_df['ClinSigSimple']
features_df['Target'] = target

# %% [markdown]
# features + target:

# %%
features_df.head(35)
# Out:
#    cadd_phred  cadd_raw  revel  sift_score polyphen_score  blosum62  \
# 0        29.2  5.203168  0.927           0           None        -3
#
#    alphamissense_score    impact       consequence  Target
# 0               0.9968  MODERATE  missense_variant       1

# %% [markdown]
# Next step:
# Complete retrieval of batch annotations from the REST API

# %% [markdown]
# U prilogu se nalazi kompletan dataset spreman za EDA (POST request ima limit od 200)

# %% [markdown]
# ---

# %%
def preuzmi_anotacije(batch_list): 
    server = "https://rest.ensembl.org" 
    ext = "/vep/homo_sapiens/region"

    headers = { 
        "Content-Type": "application/json",
        "Accept": "application/json"
    } 

    variant = batch_list  

    data = {
        "variants": variant
    } 
    param ={ 
        'canonical':1, 
        'CADD':1, 
        'AlphaMissense':1,
        'Blosum62':1,
        'LoF':1,
        'REVEL':1
    }
    try:
        r = requests.post(server + ext, headers=headers, json=data,params=param)
        r.raise_for_status()
        return r.json()
    except requests.exceptions.HTTPError as err:
        print(f"HTTP Error: {err}")

# %%
storage = []
batch_size = 150
for i in range(0,len(variantsParams),batch_size):
    batch = variantsParams[i:i + batch_size] #  150, 200 limit
    batch_result = preuzmi_anotacije(batch)
    storage.extend(batch_result)
# Out:
# HTTP Error: 503 Server Error: Service Unavailable for url: https://rest.ensembl.org/vep/homo_sapiens/region?canonical=1&CADD=1&AlphaMissense=1&Blosum62=1&LoF=1&REVEL=1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 6
#       4 batch = variantsParams[i:i + batch_size] #  150, 200 limit
#       5 batch_result = preuzmi_anotacije(batch)
# ----> 6 storage.extend(batch_result)
#
# TypeError: 'NoneType' object is not iterable

# %%
features_kompletno = []
for i,variant in enumerate(storage):
    if not isinstance(variant,dict):
        continue
    if 'transcript_consequences' not in variant:
        continue
    transcripti = variant['transcript_consequences']
    selected = select_transcript(transcripti)

    features = {
        'variant_id': i+1,
        'cadd_phred': selected.get('cadd_phred'),
        'cadd_raw': selected.get('cadd_raw'),
        'revel': selected.get('revel'),
        'sift_score': selected.get('sift_score'),
        'blosum62': selected.get('blosum62'),
        'alphamissense_score': selected.get('alphamissense', {}).get('am_pathogenicity'),
        'impact': selected.get('impact'),
        'consequence': selected.get('consequence_terms', [None])[0]
    }
    
    features_kompletno.append(features)

# %%
print(features_kompletno[-1]['variant_id'])
# 2647
# Out:
# 2647

# %%
svi_redovi = []
for i in features_kompletno:
    ime_kolone = i.keys()
    redovi = i.values()
    svi_redovi.append(list(redovi))

# %%
to_append = pd.DataFrame(data=svi_redovi,columns=ime_kolone)

# %%
# dataset with annotations
to_append.shape
# Out:
# (2646, 9)

# %%
# pocetni dataset
dataset.shape
dataset
# Out:
#      Chromosome    Start ReferenceAlleleVCF AlternateAlleleVCF GeneSymbol  \
# 0            17  7674221                  G                  A       TP53
# 1            17  7674191                  C                  T       TP53
# 2            17  7674230                  C                  A       TP53
# 3            17  7674208                  A                  G       TP53
# 4            17  7676154                  G                  C       TP53
# ...         ...      ...                ...                ...        ...
# 2658         17  7676070                  T                  G       TP53
# 2659         17  7673762                  T                  C       TP53
# 2660         17  7669609                  T                  G       TP53
# 2661         17  7675221                  T                  G       TP53
# 2662         17  7677724                  A                  G       TP53
#
#       ClinSigSimple        vcf_format
# 0                 1  17 7674221 . G A
# 1                 1  17 7674191 . C T
# 2                 1  17 7674230 . C A
# 3                 1  17 7674208 . A G
# 4                 1  17 7676154 . G C
# ...             ...               ...
# 2658              0  17 7676070 . T G
# 2659              0  17 7673762 . T C
# 2660              0  17 7669609 . T G
# 2661              1  17 7675221 . T G
# 2662              0  17 7677724 . A G
#
# [2647 rows x 7 columns]

# %%
Path.cwd()
# Out:
# WindowsPath('c:/Users/Admin/ML/tp53_variant_classification/notebooks')

# %%
complete_dataset = pd.concat([dataset,to_append],axis=1)
complete_dataset.to_csv('c:/Users/Admin/ML/tp53_variant_classification/data/processed/dataset_raw.csv')

# %%
complete_dataset.shape

# %% [markdown]
# ---
